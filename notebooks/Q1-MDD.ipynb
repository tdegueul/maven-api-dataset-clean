# %% [markdown]
# # Analysis of Q1 on the Maven Dependency Dataset (MDD)
#
# This document is the first chapter of a set of notebooks that accompany the paper "Breaking Bad? Semantic Versioning and Impact of Breaking Changes in Maven Central". In this chapter, we investigate Q1 and its corresponding null hypothesis.
#
# **Q1**: How are semantic versioning principles applied in the Maven Central Repository in terms of breaking changes?
#
# **H$_1$**: BCs are widespread without regard for semantic versioning principles.

# %% [markdown]
# ---
#
# ## Table of Contents
# <div class="toc" style="margin-top: 1em;">
#     <ul class="toc-item">
#         <li>
#             <span><a href="#Setup" data-toc-modified-id="Setup">Setup</a></span>
#         </li>
#         <li>
#             <span><a href="#Dataset" data-toc-modified-id="Dataset">Dataset</a></span>
#             <ul class="toc-item">
#                 <li>
#                     <span><a href="#Load-Dataset" data-toc-modified-id="Load-Dataset">Load Dataset</a></span>
#                 </li>
#                 <li>
#                     <span><a href="#Clean-Dataset" data-toc-modified-id="Clean-Dataset">Clean Dataset</a></span>
#                 </li>
#                 <li>
#                     <span><a href="#Finalize-Dataset" data-toc-modified-id="Finalize-Dataset">Finalize Dataset</a></span>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <span><a href="#Exploratory-Data-Analysis-(EDA)" data-toc-modified-id="Exploratory-Data-Analysis-(EDA)">Exploratory Data Analysis (EDA)</a></span>
#             <ul class="toc-item">
#                 <li>
#                     <span><a href="#Dataset-Summary" data-toc-modified-id="Dataset-Summary">Dataset Summary</a></span>
#                 </li>
#                 <li>
#                     <span><a href="#Descriptive-Statistics" data-toc-modified-id="Descriptive-Statistics">Descriptive Statistics</a></span>
#                 </li>
#                 <li>
#                     <span><a href="#Java-Versions" data-toc-modified-id="Java-Versions">Java Versions</a></span>
#                 </li>
#                 <li>
#                     <span><a href="#Semantic-Versioning-Levels" data-toc-modified-id="Semantic-Versioning-Levels">Semantic Versioning Levels</a></span>
#                 </li>
#                 <li>
#                     <span><a href="#Interval-Between-Releases" data-toc-modified-id="Interval-Between-Releases">Interval Between Releases</a></span>
#                 </li>
#                 <li>
#                     <span><a href="#Age" data-toc-modified-id="Age">Age</a></span>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <span><a href="#Results" data-toc-modified-id="Results">Results</a></span>
#             <ul class="toc-item">
#                 <li>
#                     <span><a href="#Breaking-Upgrades" data-toc-modified-id="Breaking-Upgrades">Breaking Upgrades</a></span>
#                 </li>
#                 <li>
#                     <span><a href="#Number-of-Breaking-Changes" data-toc-modified-id="Number-of-Breaking-Changes">Number of Breaking Changes</a></span>
#                 </li>
#                 <li>
#                     <span><a href="#Breaking-Change-Types" data-toc-modified-id="Breaking-Change-Types">Breaking Change Types</a></span>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <span><a href="#EOF" data-toc-modified-id="EOF">EOF</a></span>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# ---
#
# ## Setup

# %%
# Import required libraries
library(ggplot2)
library(tidyverse)
library(ggthemes)

# Set theme
theme_set(theme_stata())
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 3.5.2”
# Warning message:
# “package ‘tidyverse’ was built under R version 3.5.2”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ✔ purrr   0.3.3
#
# Warning message:
# “package ‘tidyr’ was built under R version 3.5.2”
# Warning message:
# “package ‘purrr’ was built under R version 3.5.2”
# Warning message:
# “package ‘stringr’ was built under R version 3.5.2”
# Warning message:
# “package ‘forcats’ was built under R version 3.5.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Warning message:
# “package ‘ggthemes’ was built under R version 3.5.2”

# %% [markdown]
# ---
#
# ## Dataset

# %% [markdown]
# ### Load Dataset
#
# First, we load the `deltas-raemaekers.csv` dataset which contains information about breaking changes computed by Maracas on the selected upgrades of the MDD.

# %%
deltas <- read.csv("../code/cypher-queries/data/gen/deltas-raemaekers.csv", stringsAsFactors=FALSE, colClasses=c("level"="factor", "year"="factor", "java_version_v1"="factor", "java_version_v2"="factor", "expected_level"="factor"))
sprintf("Successfully loaded %d deltas", nrow(deltas))
head(deltas)
# Out:
# [1] "Successfully loaded 13193 deltas"
#   group                        artifact                   v1    v2    level
# 1 org.apache.jackrabbit        jackrabbit-text-extractors 1.6.0 1.6.1 PATCH
# 2 org.apache.jackrabbit        jackrabbit-text-extractors 1.5.0 1.6.0 MINOR
# 3 org.apache.struts            struts2-rest-plugin        2.2.1 2.2.3 PATCH
# 4 org.springframework.security spring-security-core-tiger 2.0.1 2.0.2 PATCH
# 5 org.springframework.security spring-security-core-tiger 2.0.2 2.0.3 PATCH
# 6 org.springframework.security spring-security-core-tiger 2.0.3 2.0.4 PATCH
#   language year age_diff distance clients ⋯ fieldLessAccessible_unstableAnnon
# 1 unknown  2010  1        8        1      ⋯ -1
# 2 unknown  2009  1       30        4      ⋯ -1
# 3 java     2011 22        2        4      ⋯  0
# 4 java     2008  2        1       30      ⋯  0
# 5 java     2008 19        1        3      ⋯  0
# 6 java     2008  8        1       66      ⋯  0
#   fieldMoreAccessible_unstableAnnon constructorRemoved_unstableAnnon
# 1 -1                                -1
# 2 -1                                -1
# 3  0                                 0
# 4  0                                 0
# 5  0                                 0
# 6  0                                 0
#   constructorLessAccessible_unstableAnnon unstableAnnons
# 1 -1                                      {}
# 2 -1                                      {}
# 3  0                                      {}
# 4  0                                      {}
# 5  0                                      {}
# 6  0                                      {}
#   jar_v1
# 1 -1
# 2 -1
# 3 /home/dig/repositories/maven-api-dataset/code/cypher-queries/local-repo/org/apache/struts/struts2-rest-plugin/2.2.1/struts2-rest-plugin-2.2.1.jar
# 4 /home/dig/repositories/maven-api-dataset/code/cypher-queries/local-repo/org/springframework/security/spring-security-core-tiger/2.0.1/spring-security-core-tiger-2.0.1.jar
# 5 /home/dig/repositories/maven-api-dataset/code/cypher-queries/local-repo/org/springframework/security/spring-security-core-tiger/2.0.2/spring-security-core-tiger-2.0.2.jar
# 6 /home/dig/repositories/maven-api-dataset/code/cypher-queries/local-repo/org/springframework/security/spring-security-core-tiger/2.0.3/spring-security-core-tiger-2.0.3.jar
#   jar_v2
# 1 -1
# 2 -1
# 3 /home/dig/repositories/maven-api-dataset/code/cypher-queries/local-repo/org/apache/struts/struts2-rest-plugin/2.2.3/struts2-rest-plugin-2.2.3.jar
# 4 /home/dig/repositories/maven-api-dataset/code/cypher-queries/local-repo/org/springframework/security/spring-security-core-tiger/2.0.2/spring-security-core-tiger-2.0.2.jar
# 5 /home/dig/repositories/maven-api-dataset/code/cypher-queries/local-repo/org/springframework/security/spring-security-core-tiger/2.0.3/spring-security-core-tiger-2.0.3.jar
# 6 /home/dig/repositories/maven-api-dataset/code/cypher-queries/local-repo/org/springframework/security/spring-security-core-tiger/2.0.4/spring-security-core-tiger-2.0.4.jar
#   delta
# 1 -1
# 2 -1
# 3 /home/dig/repositories/maven-api-dataset/code/cypher-queries/data/gen/deltas/org.apache.struts/struts2-rest-plugin/2.2.1_to_2.2.3.delta
# 4 /home/dig/repositories/maven-api-dataset/code/cypher-queries/data/gen/deltas/org.springframework.security/spring-security-core-tiger/2.0.1_to_2.0.2.delta
# 5 /home/dig/repositories/maven-api-dataset/code/cypher-queries/data/gen/deltas/org.springframework.security/spring-security-core-tiger/2.0.2_to_2.0.3.delta
# 6 /home/dig/repositories/maven-api-dataset/code/cypher-queries/data/gen/deltas/org.springframework.security/spring-security-core-tiger/2.0.3_to_2.0.4.delta
#   exception     t
# 1 jar-not-found 2
# 2 jar-not-found 2
# 3 -1            3
# 4 -1            0
# 5 -1            0
# 6 -1            0

# %% [markdown]
# ### Clean Dataset
#
# Here, we clean the dataset to discard the upgrades and deltas not complying with our requirements.

# %%
# What issues did we encounter when attempting to compute the deltas? (Java version >= 8, JAR not produced from Java code, JAR not found on Maven Central, etc.)
table(deltas$exception)
# Out:
#                   -1     exception-raised invalid-java-version
#                11751                    2                  641
#     invalid-language        jar-not-found
#                  493                  306

# %%
# Which languages did we find?
table(deltas$language)
# Out:
# clojure  groovy    java   scala unknown
#       2      71   12345      76     699

# %%
# Discard all deltas that raised an exception
deltas <- subset(deltas, exception == -1)

# Discard all deltas for upgrades that do not contain any code
sprintf("%d deltas correspond to JARs not containing any code", nrow(subset(deltas, declarations_v1 == 0 & declarations_v2 == 0)))
deltas <- subset(deltas, declarations_v1 > 0 | declarations_v2 > 0)

# Discard all deltas where v1 was released _after_ v2
sprintf("%d where v1 was released after v2", nrow(subset(deltas, age_diff < 0)))
deltas <- subset(deltas, age_diff >= 0)

sprintf("%d remaining deltas after cleaning", nrow(deltas))
# Out:
# [1] "0 deltas correspond to JARs not containing any code"
# [1] "309 where v1 was released after v2"
# [1] "11442 remaining deltas after cleaning"

# %%
# Remove cases where dates are used as versions (e.g. 20081010.0.1, 1.20081010.1, 1.0.20081010)
deltas <- deltas[grep("^[0-9]{0,7}[.][0-9]{0,7}([.][0-9]{0,7})?$", deltas$v1),]
deltas <- deltas[grep("^[0-9]{0,7}[.][0-9]{0,7}([.][0-9]{0,7})?$", deltas$v2),]

deltas <- deltas[!grepl("^2[0-9]{3}[.][0-9]{2}([.][0-9]{2})?$", deltas$v1),]
deltas <- deltas[!grepl("^[0-9]{2}[.][0-9]{2}[.]2[0-9]{3}$", deltas$v1),]
deltas <- deltas[!grepl("^[0-9]{2}[.]2[0-9]{3}$", deltas$v1),]

deltas <- deltas[!grepl("^2[0-9]{3}[.][0-9]{2}([.][0-9]{2})?$", deltas$v2),]
deltas <- deltas[!grepl("^[0-9]{2}[.][0-9]{2}[.]2[0-9]{3}$", deltas$v2),]
deltas <- deltas[!grepl("^[0-9]{2}[.]2[0-9]{3}$", deltas$v2),]

sprintf("%d deltas remaining after removing the ones with dates as versions", nrow(deltas))
# Out:
# [1] "11411 deltas remaining after removing the ones with dates as versions"

# %%
# Keep only pairs released before 2012 to match the original study's corpus
deltas <- subset(deltas, as.numeric(as.character(year)) <= 2011)
sprintf("%d deltas remaining after removing the ones with release date >= 2012", nrow(deltas))
# Out:
# [1] "11384 deltas remaining after removing the ones with release date >= 2012"

# %% [markdown]
# ### Finalize Dataset
# Here, we incorporate additional derived information into the dataset.

# %%
# Add column with all BCs excluding the ones related to: 
# - annotationDeprecatedAdded: not a BC
# - methodAddedToPublicClass: not a BC
# - classNowCheckedException: not binary incompatible
# - methodNowThrowsCheckedException: not binary incompatible
# - fieldStaticAndOverridesStatic: lack of alignment with JLS
# - superclassModifiedIncompatible: lack of alignment with JLS
# - methodIsStaticAndOverridesNotStatic: lack of alignment with JLS
# - methodAbstractAddedInSuperclass: covered by other BC
# - methodAbstractAddedInImplementedInterface: covered by other BC
# - methodLessAccessibleThanInSuperclass: covered by other BC
# - fieldLessAccessibleThanInSuperclass: covered by other BC
# - fieldRemovedInSuperclass: covered by other BC
# - methodRemovedInSuperclass: covered by other BC

deltas$bcs_clean = deltas$bcs -
    deltas$annotationDeprecatedAdded -
    deltas$methodAddedToPublicClass - 
    deltas$classNowCheckedException - 
    deltas$methodNowThrowsCheckedException -
    deltas$fieldStaticAndOverridesStatic -
    deltas$superclassModifiedIncompatible - 
    deltas$methodIsStaticAndOverridesNotStatic -
    deltas$methodAbstractAddedInSuperclass -
    deltas$methodAbstractAddedInImplementedInterface -
    deltas$methodLessAccessibleThanInSuperclass - 
    deltas$fieldLessAccessibleThanInSuperclass -
    deltas$fieldRemovedInSuperclass -
    deltas$methodRemovedInSuperclass

# Same thing for the stable part of the API
deltas$bcs_clean_stable = deltas$bcs_stable -
    deltas$annotationDeprecatedAdded_stable -
    deltas$methodAddedToPublicClass_stable - 
    deltas$classNowCheckedException_stable - 
    deltas$methodNowThrowsCheckedException_stable -
    deltas$fieldStaticAndOverridesStatic_stable -
    deltas$superclassModifiedIncompatible_stable - 
    deltas$methodIsStaticAndOverridesNotStatic_stable -
    deltas$methodAbstractAddedInSuperclass_stable -
    deltas$methodAbstractAddedInImplementedInterface_stable -
    deltas$methodLessAccessibleThanInSuperclass_stable - 
    deltas$fieldLessAccessibleThanInSuperclass_stable -
    deltas$fieldRemovedInSuperclass_stable -
    deltas$methodRemovedInSuperclass_stable

# %%
# Add columns with BCs ratios (i.e. BCs / V1 declarations)
deltas$bcs_ratio_clean = deltas$bcs_clean / deltas$declarations_v1
deltas$bcs_ratio_clean_stable = deltas$bcs_clean_stable / deltas$declarations_v1

# %%
# Assign the 'DEV' semver level to versions of the form 0.x.x
levels(deltas$level) <- c(levels(deltas$level), "DEV")
deltas[grepl("^0[.]", deltas$v1),]$level = "DEV"

# %% [markdown]
# ---
#
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Dataset Summary

# %%
sprintf("Final size of the dataset: %s deltas", nrow(deltas))
summary(deltas)
# Out:
# [1] "Final size of the dataset: 11384 deltas"
#     group             artifact              v1                 v2
#  Length:11384       Length:11384       Length:11384       Length:11384
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#    level        language              year         age_diff
#  MAJOR: 253   Length:11384       2010   :3500   Min.   : 0.00
#  MINOR:2413   Class :character   2011   :2895   1st Qu.: 6.00
#  PATCH:7728   Mode  :character   2009   :2378   Median :14.00
#  DEV  : 990                      2008   :1481   Mean   :14.02
#                                  2007   : 623   3rd Qu.:22.00
#                                  2006   : 293   Max.   :30.00
#                                  (Other): 214
#     distance         clients        client_groups        releases
#  Min.   :  1.00   Min.   :   1.00   Min.   :  1.000   Min.   : 1.000
#  1st Qu.:  1.00   1st Qu.:   1.00   1st Qu.:  1.000   1st Qu.: 1.000
#  Median :  1.00   Median :   3.00   Median :  1.000   Median : 1.000
#  Mean   :  1.19   Mean   :  24.31   Mean   :  3.058   Mean   : 1.228
#  3rd Qu.:  1.00   3rd Qu.:   8.00   3rd Qu.:  2.000   3rd Qu.: 1.000
#  Max.   :287.00   Max.   :6153.00   Max.   :522.000   Max.   :55.000
#
#       age            activity        java_version_v1 java_version_v2
#  Min.   :  1.00   Min.   : 0.01409   49     :7877    49     :7965
#  1st Qu.:  1.00   1st Qu.: 0.25000   48     :1472    48     :1397
#  Median :  2.00   Median : 0.50000   50     : 926    50     : 989
#  Mean   :  5.55   Mean   : 0.53249   47     : 633    47     : 631
#  3rd Qu.:  5.00   3rd Qu.: 1.00000   46     : 476    46     : 402
#  Max.   :146.00   Max.   :18.00000   -1     :   0    -1     :   0
#                                      (Other):   0    (Other):   0
#  declarations_v1  api_declarations_v1 declarations_v2    api_declarations_v2
#  Min.   :     1   Min.   :     1.0    Min.   :     1.0   Min.   :     1.0
#  1st Qu.:    71   1st Qu.:    49.0    1st Qu.:    73.0   1st Qu.:    50.0
#  Median :   280   Median :   200.5    Median :   290.5   Median :   207.0
#  Mean   :  2076   Mean   :  1515.6    Mean   :  2135.6   Mean   :  1560.0
#  3rd Qu.:  1276   3rd Qu.:   891.2    3rd Qu.:  1308.2   3rd Qu.:   926.8
#  Max.   :218274   Max.   :159478.0    Max.   :218274.0   Max.   :159478.0
#
#       bcs           bin_compatible     src_compatible     expected_level
#  Min.   :    0.00   Length:11384       Length:11384       -1     :   0
#  1st Qu.:    0.00   Class :character   Class :character   MAJOR  :4800
#  Median :    0.00   Mode  :character   Mode  :character   MINOR  : 297
#  Mean   :   93.14                                         PATCH  :6085
#  3rd Qu.:    9.00                                         UNKNOWN: 202
#  Max.   :34911.00
#
#     changes            added            removed            modified
#  Min.   :    0.0   Min.   :    0.0   Min.   :    0.00   Min.   :   0.000
#  1st Qu.:    0.0   1st Qu.:    0.0   1st Qu.:    0.00   1st Qu.:   0.000
#  Median :    0.0   Median :    0.0   Median :    0.00   Median :   0.000
#  Mean   :  162.2   Mean   :  100.3   Mean   :   52.13   Mean   :   9.773
#  3rd Qu.:   20.0   3rd Qu.:   11.0   3rd Qu.:    1.00   3rd Qu.:   3.000
#  Max.   :78673.0   Max.   :74999.0   Max.   :47054.00   Max.   :6399.000
#
#   broken_types      broken_methods     broken_fields       bcs_on_types
#  Min.   :   0.000   Min.   :    0.00   Min.   :   0.000   Min.   :   0.000
#  1st Qu.:   0.000   1st Qu.:    0.00   1st Qu.:   0.000   1st Qu.:   0.000
#  Median :   0.000   Median :    0.00   Median :   0.000   Median :   0.000
#  Mean   :   8.661   Mean   :   67.83   Mean   :   6.306   Mean   :   9.371
#  3rd Qu.:   0.000   3rd Qu.:    7.00   3rd Qu.:   0.000   3rd Qu.:   0.000
#  Max.   :3030.000   Max.   :32946.00   Max.   :5319.000   Max.   :3068.000
#
#  bcs_on_methods     bcs_on_fields     annotationDeprecatedAdded
#  Min.   :    0.00   Min.   :   0.00   Min.   :  0.0000
#  1st Qu.:    0.00   1st Qu.:   0.00   1st Qu.:  0.0000
#  Median :    0.00   Median :   0.00   Median :  0.0000
#  Mean   :   68.07   Mean   :   6.35   Mean   :  0.3843
#  3rd Qu.:    7.00   3rd Qu.:   0.00   3rd Qu.:  0.0000
#  Max.   :32953.00   Max.   :5323.00   Max.   :159.0000
#
#   classRemoved      classNowAbstract   classNowFinal      classNoLongerPublic
#  Min.   :   0.000   Min.   : 0.00000   Min.   :  0.0000   Min.   : 0.00000
#  1st Qu.:   0.000   1st Qu.: 0.00000   1st Qu.:  0.0000   1st Qu.: 0.00000
#  Median :   0.000   Median : 0.00000   Median :  0.0000   Median : 0.00000
#  Mean   :   3.634   Mean   : 0.02644   Mean   :  0.1145   Mean   : 0.01607
#  3rd Qu.:   0.000   3rd Qu.: 0.00000   3rd Qu.:  0.0000   3rd Qu.: 0.00000
#  Max.   :2669.000   Max.   :31.00000   Max.   :381.0000   Max.   :16.00000
#
#  classTypeChanged   classNowCheckedException classLessAccessible
#  Min.   : 0.00000   Min.   :0.0000000        Min.   : 0.00000
#  1st Qu.: 0.00000   1st Qu.:0.0000000        1st Qu.: 0.00000
#  Median : 0.00000   Median :0.0000000        Median : 0.00000
#  Mean   : 0.02486   Mean   :0.0003514        Mean   : 0.01651
#  3rd Qu.: 0.00000   3rd Qu.:0.0000000        3rd Qu.: 0.00000
#  Max.   :20.00000   Max.   :1.0000000        Max.   :16.00000
#
#  superclassRemoved  superclassAdded    superclassModifiedIncompatible
#  Min.   :   0.000   Min.   :  0.0000   Min.   :0
#  1st Qu.:   0.000   1st Qu.:  0.0000   1st Qu.:0
#  Median :   0.000   Median :  0.0000   Median :0
#  Mean   :   3.845   Mean   :  0.1647   Mean   :0
#  3rd Qu.:   0.000   3rd Qu.:  0.0000   3rd Qu.:0
#  Max.   :2679.000   Max.   :104.0000   Max.   :0
#
#  interfaceAdded     interfaceRemoved   methodRemoved
#  Min.   :   0.000   Min.   :   0.000   Min.   :    0.00
#  1st Qu.:   0.000   1st Qu.:   0.000   1st Qu.:    0.00
#  Median :   0.000   Median :   0.000   Median :    0.00
#  Mean   :   2.203   Mean   :   5.338   Mean   :   19.03
#  3rd Qu.:   0.000   3rd Qu.:   0.000   3rd Qu.:    0.00
#  Max.   :1032.000   Max.   :3717.000   Max.   :13695.00
#
#  methodRemovedInSuperclass methodLessAccessible
#  Min.   :   0.000          Min.   : 0.000
#  1st Qu.:   0.000          1st Qu.: 0.000
#  Median :   0.000          Median : 0.000
#  Mean   :   2.573          Mean   : 0.102
#  3rd Qu.:   0.000          3rd Qu.: 0.000
#  Max.   :2446.000          Max.   :28.000
#
#  methodLessAccessibleThanInSuperclass methodMoreAccessible
#  Min.   :0                            Min.   :  0.0000
#  1st Qu.:0                            1st Qu.:  0.0000
#  Median :0                            Median :  0.0000
#  Mean   :0                            Mean   :  0.2738
#  3rd Qu.:0                            3rd Qu.:  0.0000
#  Max.   :0                            Max.   :442.0000
#
#  methodIsStaticAndOverridesNotStatic methodReturnTypeChanged methodNowAbstract
#  Min.   :0                           Min.   :   0.0000       Min.   : 0.00000
#  1st Qu.:0                           1st Qu.:   0.0000       1st Qu.: 0.00000
#  Median :0                           Median :   0.0000       Median : 0.00000
#  Mean   :0                           Mean   :   0.7811       Mean   : 0.05824
#  3rd Qu.:0                           3rd Qu.:   0.0000       3rd Qu.: 0.00000
#  Max.   :0                           Max.   :1971.0000       Max.   :95.00000
#
#  methodNowFinal     methodNowStatic    methodNoLongerStatic
#  Min.   :  0.0000   Min.   : 0.00000   Min.   :  0.00000
#  1st Qu.:  0.0000   1st Qu.: 0.00000   1st Qu.:  0.00000
#  Median :  0.0000   Median : 0.00000   Median :  0.00000
#  Mean   :  0.1168   Mean   : 0.02152   Mean   :  0.03268
#  3rd Qu.:  0.0000   3rd Qu.: 0.00000   3rd Qu.:  0.00000
#  Max.   :442.0000   Max.   :29.00000   Max.   :119.00000
#
#  methodAddedToInterface methodAddedToPublicClass
#  Min.   :  0.000        Min.   :    0.00
#  1st Qu.:  0.000        1st Qu.:    0.00
#  Median :  0.000        Median :    0.00
#  Mean   :  1.131        Mean   :   41.27
#  3rd Qu.:  0.000        3rd Qu.:    4.00
#  Max.   :890.000        Max.   :30252.00
#
#  methodNowThrowsCheckedException methodAbstractAddedToClass
#  Min.   :  0.0000                Min.   :  0.0000
#  1st Qu.:  0.0000                1st Qu.:  0.0000
#  Median :  0.0000                Median :  0.0000
#  Mean   :  0.1586                Mean   :  0.1565
#  3rd Qu.:  0.0000                3rd Qu.:  0.0000
#  Max.   :332.0000                Max.   :139.0000
#
#  methodAbstractAddedInSuperclass methodAbstractAddedInImplementedInterface
#  Min.   : 0.00000                Min.   :  0.00000
#  1st Qu.: 0.00000                1st Qu.:  0.00000
#  Median : 0.00000                Median :  0.00000
#  Mean   : 0.02609                Mean   :  0.05446
#  3rd Qu.: 0.00000                3rd Qu.:  0.00000
#  Max.   :56.00000                Max.   :109.00000
#
#  methodNewDefault methodAbstractNowDefault fieldStaticAndOverridesStatic
#  Min.   :0        Min.   :0                Min.   : 0.000000
#  1st Qu.:0        1st Qu.:0                1st Qu.: 0.000000
#  Median :0        Median :0                Median : 0.000000
#  Mean   :0        Mean   :0                Mean   : 0.006764
#  3rd Qu.:0        3rd Qu.:0                3rd Qu.: 0.000000
#  Max.   :0        Max.   :0                Max.   :25.000000
#
#  fieldLessAccessibleThanInSuperclass fieldNowFinal       fieldNowStatic
#  Min.   :0                           Min.   :  0.00000   Min.   : 0.000000
#  1st Qu.:0                           1st Qu.:  0.00000   1st Qu.: 0.000000
#  Median :0                           Median :  0.00000   Median : 0.000000
#  Mean   :0                           Mean   :  0.09267   Mean   : 0.005183
#  3rd Qu.:0                           3rd Qu.:  0.00000   3rd Qu.: 0.000000
#  Max.   :0                           Max.   :145.00000   Max.   :16.000000
#
#  fieldNoLongerStatic fieldTypeChanged     fieldRemoved
#  Min.   : 0.000000   Min.   :   0.0000   Min.   :   0.00
#  1st Qu.: 0.000000   1st Qu.:   0.0000   1st Qu.:   0.00
#  Median : 0.000000   Median :   0.0000   Median :   0.00
#  Mean   : 0.006588   Mean   :   0.3015   Mean   :   5.62
#  3rd Qu.: 0.000000   3rd Qu.:   0.0000   3rd Qu.:   0.00
#  Max.   :15.000000   Max.   :1899.0000   Max.   :5280.00
#
#  fieldRemovedInSuperclass fieldLessAccessible fieldMoreAccessible
#  Min.   :   0.0000        Min.   :  0.0000    Min.   :  0.0000
#  1st Qu.:   0.0000        1st Qu.:  0.0000    1st Qu.:  0.0000
#  Median :   0.0000        Median :  0.0000    Median :  0.0000
#  Mean   :   0.6056        Mean   :  0.1046    Mean   :  0.1853
#  3rd Qu.:   0.0000        3rd Qu.:  0.0000    3rd Qu.:  0.0000
#  Max.   :1347.0000        Max.   :146.0000    Max.   :171.0000
#
#  constructorRemoved constructorLessAccessible   bcs_stable
#  Min.   :   0.000   Min.   : 0.0000           Min.   :    0.00
#  1st Qu.:   0.000   1st Qu.: 0.0000           1st Qu.:    0.00
#  Median :   0.000   Median : 0.0000           Median :    0.00
#  Mean   :   4.602   Mean   : 0.0621           Mean   :   87.63
#  3rd Qu.:   0.000   3rd Qu.: 0.0000           3rd Qu.:    8.00
#  Max.   :3156.000   Max.   :49.0000           Max.   :34903.00
#
#  bin_compatible_stable src_compatible_stable expected_level_stable
#  Length:11384          Length:11384          Length:11384
#  Class :character      Class :character      Class :character
#  Mode  :character      Mode  :character      Mode  :character
#
#
#
#
#  changes_stable     added_stable      removed_stable     modified_stable
#  Min.   :    0.0   Min.   :    0.00   Min.   :    0.00   Min.   :   0.000
#  1st Qu.:    0.0   1st Qu.:    0.00   1st Qu.:    0.00   1st Qu.:   0.000
#  Median :    0.0   Median :    0.00   Median :    0.00   Median :   0.000
#  Mean   :  153.4   Mean   :   95.36   Mean   :   48.64   Mean   :   9.378
#  3rd Qu.:   19.0   3rd Qu.:   11.00   3rd Qu.:    1.00   3rd Qu.:   3.000
#  Max.   :78655.0   Max.   :74981.00   Max.   :47054.00   Max.   :6399.000
#
#  broken_types_stable broken_methods_stable broken_fields_stable
#  Min.   :   0.000    Min.   :    0.00      Min.   :   0.000
#  1st Qu.:   0.000    1st Qu.:    0.00      1st Qu.:   0.000
#  Median :   0.000    Median :    0.00      Median :   0.000
#  Mean   :   8.234    Mean   :   64.05      Mean   :   5.652
#  3rd Qu.:   0.000    3rd Qu.:    7.00      3rd Qu.:   0.000
#  Max.   :2964.000    Max.   :32938.00      Max.   :4189.000
#
#  bcs_on_types_stable bcs_on_methods_stable bcs_on_fields_stable
#  Min.   :   0.000    Min.   :    0.00      Min.   :   0.000
#  1st Qu.:   0.000    1st Qu.:    0.00      1st Qu.:   0.000
#  Median :   0.000    Median :    0.00      Median :   0.000
#  Mean   :   8.914    Mean   :   64.28      Mean   :   5.695
#  3rd Qu.:   0.000    3rd Qu.:    7.00      3rd Qu.:   0.000
#  Max.   :3001.000    Max.   :32945.00      Max.   :4189.000
#
#  annotationDeprecatedAdded_stable classRemoved_stable classNowAbstract_stable
#  Min.   :  0.0000                 Min.   :   0.000    Min.   : 0.00000
#  1st Qu.:  0.0000                 1st Qu.:   0.000    1st Qu.: 0.00000
#  Median :  0.0000                 Median :   0.000    Median : 0.00000
#  Mean   :  0.3666                 Mean   :   3.431    Mean   : 0.02583
#  3rd Qu.:  0.0000                 3rd Qu.:   0.000    3rd Qu.: 0.00000
#  Max.   :156.0000                 Max.   :2669.000    Max.   :31.00000
#
#  classNowFinal_stable classNoLongerPublic_stable classTypeChanged_stable
#  Min.   :  0.0000     Min.   : 0.00000           Min.   : 0.00000
#  1st Qu.:  0.0000     1st Qu.: 0.00000           1st Qu.: 0.00000
#  Median :  0.0000     Median : 0.00000           Median : 0.00000
#  Mean   :  0.1102     Mean   : 0.01309           Mean   : 0.02407
#  3rd Qu.:  0.0000     3rd Qu.: 0.00000           3rd Qu.: 0.00000
#  Max.   :381.0000     Max.   :16.00000           Max.   :20.00000
#
#  classNowCheckedException_stable classLessAccessible_stable
#  Min.   :0.0000000               Min.   : 0.00000
#  1st Qu.:0.0000000               1st Qu.: 0.00000
#  Median :0.0000000               Median : 0.00000
#  Mean   :0.0002635               Mean   : 0.01353
#  3rd Qu.:0.0000000               3rd Qu.: 0.00000
#  Max.   :1.0000000               Max.   :16.00000
#
#  superclassRemoved_stable superclassAdded_stable
#  Min.   :   0.000         Min.   :  0.0000
#  1st Qu.:   0.000         1st Qu.:  0.0000
#  Median :   0.000         Median :  0.0000
#  Mean   :   3.638         Mean   :  0.1565
#  3rd Qu.:   0.000         3rd Qu.:  0.0000
#  Max.   :2679.000         Max.   :104.0000
#
#  superclassModifiedIncompatible_stable interfaceAdded_stable
#  Min.   :0                             Min.   :   0.000
#  1st Qu.:0                             1st Qu.:   0.000
#  Median :0                             Median :   0.000
#  Mean   :0                             Mean   :   2.123
#  3rd Qu.:0                             3rd Qu.:   0.000
#  Max.   :0                             Max.   :1032.000
#
#  interfaceRemoved_stable methodRemoved_stable methodRemovedInSuperclass_stable
#  Min.   :   0.000        Min.   :    0.00     Min.   :   0.000
#  1st Qu.:   0.000        1st Qu.:    0.00     1st Qu.:   0.000
#  Median :   0.000        Median :    0.00     Median :   0.000
#  Mean   :   4.947        Mean   :   17.61     Mean   :   2.458
#  3rd Qu.:   0.000        3rd Qu.:    0.00     3rd Qu.:   0.000
#  Max.   :3717.000        Max.   :13695.00     Max.   :2397.000
#
#  methodLessAccessible_stable methodLessAccessibleThanInSuperclass_stable
#  Min.   : 0.00000            Min.   :0
#  1st Qu.: 0.00000            1st Qu.:0
#  Median : 0.00000            Median :0
#  Mean   : 0.08828            Mean   :0
#  3rd Qu.: 0.00000            3rd Qu.:0
#  Max.   :28.00000            Max.   :0
#
#  methodMoreAccessible_stable methodIsStaticAndOverridesNotStatic_stable
#  Min.   :  0.0000            Min.   :0
#  1st Qu.:  0.0000            1st Qu.:0
#  Median :  0.0000            Median :0
#  Mean   :  0.2621            Mean   :0
#  3rd Qu.:  0.0000            3rd Qu.:0
#  Max.   :442.0000            Max.   :0
#
#  methodReturnTypeChanged_stable methodNowAbstract_stable methodNowFinal_stable
#  Min.   :   0.0000              Min.   : 0.00000         Min.   :  0.0000
#  1st Qu.:   0.0000              1st Qu.: 0.00000         1st Qu.:  0.0000
#  Median :   0.0000              Median : 0.00000         Median :  0.0000
#  Mean   :   0.7599              Mean   : 0.05631         Mean   :  0.1151
#  3rd Qu.:   0.0000              3rd Qu.: 0.00000         3rd Qu.:  0.0000
#  Max.   :1971.0000              Max.   :95.00000         Max.   :442.0000
#
#  methodNowStatic_stable methodNoLongerStatic_stable
#  Min.   : 0.00000       Min.   :  0.00000
#  1st Qu.: 0.00000       1st Qu.:  0.00000
#  Median : 0.00000       Median :  0.00000
#  Mean   : 0.01871       Mean   :  0.03171
#  3rd Qu.: 0.00000       3rd Qu.:  0.00000
#  Max.   :29.00000       Max.   :119.00000
#
#  methodAddedToInterface_stable methodAddedToPublicClass_stable
#  Min.   :  0.000               Min.   :    0.00
#  1st Qu.:  0.000               1st Qu.:    0.00
#  Median :  0.000               Median :    0.00
#  Mean   :  1.098               Mean   :   39.24
#  3rd Qu.:  0.000               3rd Qu.:    4.00
#  Max.   :890.000               Max.   :30244.00
#
#  methodNowThrowsCheckedException_stable methodAbstractAddedToClass_stable
#  Min.   :  0.0000                       Min.   :  0.0000
#  1st Qu.:  0.0000                       1st Qu.:  0.0000
#  Median :  0.0000                       Median :  0.0000
#  Mean   :  0.1566                       Mean   :  0.1475
#  3rd Qu.:  0.0000                       3rd Qu.:  0.0000
#  Max.   :332.0000                       Max.   :139.0000
#
#  methodAbstractAddedInSuperclass_stable
#  Min.   : 0.00000
#  1st Qu.: 0.00000
#  Median : 0.00000
#  Mean   : 0.02486
#  3rd Qu.: 0.00000
#  Max.   :56.00000
#
#  methodAbstractAddedInImplementedInterface_stable methodNewDefault_stable
#  Min.   :  0.00000                                Min.   :0
#  1st Qu.:  0.00000                                1st Qu.:0
#  Median :  0.00000                                Median :0
#  Mean   :  0.05341                                Mean   :0
#  3rd Qu.:  0.00000                                3rd Qu.:0
#  Max.   :109.00000                                Max.   :0
#
#  methodAbstractNowDefault_stable fieldStaticAndOverridesStatic_stable
#  Min.   :0                       Min.   : 0.000000
#  1st Qu.:0                       1st Qu.: 0.000000
#  Median :0                       Median : 0.000000
#  Mean   :0                       Mean   : 0.006764
#  3rd Qu.:0                       3rd Qu.: 0.000000
#  Max.   :0                       Max.   :25.000000
#
#  fieldLessAccessibleThanInSuperclass_stable fieldNowFinal_stable
#  Min.   :0                                  Min.   :  0.00000
#  1st Qu.:0                                  1st Qu.:  0.00000
#  Median :0                                  Median :  0.00000
#  Mean   :0                                  Mean   :  0.09153
#  3rd Qu.:0                                  3rd Qu.:  0.00000
#  Max.   :0                                  Max.   :145.00000
#
#  fieldNowStatic_stable fieldNoLongerStatic_stable fieldTypeChanged_stable
#  Min.   : 0.000000     Min.   : 0.0000            Min.   :   0.0000
#  1st Qu.: 0.000000     1st Qu.: 0.0000            1st Qu.:   0.0000
#  Median : 0.000000     Median : 0.0000            Median :   0.0000
#  Mean   : 0.005007     Mean   : 0.0065            Mean   :   0.2882
#  3rd Qu.: 0.000000     3rd Qu.: 0.0000            3rd Qu.:   0.0000
#  Max.   :16.000000     Max.   :15.0000            Max.   :1899.0000
#
#  fieldRemoved_stable fieldRemovedInSuperclass_stable fieldLessAccessible_stable
#  Min.   :   0.000    Min.   :   0.000                Min.   :  0.00000
#  1st Qu.:   0.000    1st Qu.:   0.000                1st Qu.:  0.00000
#  Median :   0.000    Median :   0.000                Median :  0.00000
#  Mean   :   4.999    Mean   :   0.565                Mean   :  0.09645
#  3rd Qu.:   0.000    3rd Qu.:   0.000                3rd Qu.:  0.00000
#  Max.   :4024.000    Max.   :1324.000                Max.   :146.00000
#
#  fieldMoreAccessible_stable constructorRemoved_stable
#  Min.   :  0.0000           Min.   :   0.00
#  1st Qu.:  0.0000           1st Qu.:   0.00
#  Median :  0.0000           Median :   0.00
#  Mean   :  0.1759           Mean   :   4.37
#  3rd Qu.:  0.0000           3rd Qu.:   0.00
#  Max.   :171.0000           Max.   :3156.00
#
#  constructorLessAccessible_stable  bcs_unstable      bin_compatible_unstable
#  Min.   : 0.00000                 Min.   :    0.00   Length:11384
#  1st Qu.: 0.00000                 1st Qu.:    0.00   Class :character
#  Median : 0.00000                 Median :    0.00   Mode  :character
#  Mean   : 0.05789                 Mean   :    5.51
#  3rd Qu.: 0.00000                 3rd Qu.:    0.00
#  Max.   :49.00000                 Max.   :20783.00
#
#  src_compatible_unstable expected_level_unstable changes_unstable
#  Length:11384            Length:11384            Min.   :    0.000
#  Class :character        Class :character        1st Qu.:    0.000
#  Mode  :character        Mode  :character        Median :    0.000
#                                                  Mean   :    8.872
#                                                  3rd Qu.:    0.000
#                                                  Max.   :31462.000
#
#  added_unstable      removed_unstable    modified_unstable
#  Min.   :    0.000   Min.   :    0.000   Min.   :  0.0000
#  1st Qu.:    0.000   1st Qu.:    0.000   1st Qu.:  0.0000
#  Median :    0.000   Median :    0.000   Median :  0.0000
#  Mean   :    4.993   Mean   :    3.484   Mean   :  0.3954
#  3rd Qu.:    0.000   3rd Qu.:    0.000   3rd Qu.:  0.0000
#  Max.   :16022.000   Max.   :15247.000   Max.   :455.0000
#
#  broken_types_unstable broken_methods_unstable broken_fields_unstable
#  Min.   :  0.0000      Min.   :    0.000       Min.   :   0.000
#  1st Qu.:  0.0000      1st Qu.:    0.000       1st Qu.:   0.000
#  Median :  0.0000      Median :    0.000       Median :   0.000
#  Mean   :  0.4269      Mean   :    3.781       Mean   :   0.654
#  3rd Qu.:  0.0000      3rd Qu.:    0.000       3rd Qu.:   0.000
#  Max.   :883.0000      Max.   :13699.000       Max.   :3335.000
#
#  bcs_on_types_unstable bcs_on_methods_unstable bcs_on_fields_unstable
#  Min.   :  0.000       Min.   :    0.000       Min.   :   0.000
#  1st Qu.:  0.000       1st Qu.:    0.000       1st Qu.:   0.000
#  Median :  0.000       Median :    0.000       Median :   0.000
#  Mean   :  0.457       Mean   :    3.792       Mean   :   0.655
#  3rd Qu.:  0.000       3rd Qu.:    0.000       3rd Qu.:   0.000
#  Max.   :888.000       Max.   :13701.000       Max.   :3338.000
#
#  annotationDeprecatedAdded_unstable classRemoved_unstable
#  Min.   : 0.00000                   Min.   :  0.0000
#  1st Qu.: 0.00000                   1st Qu.:  0.0000
#  Median : 0.00000                   Median :  0.0000
#  Mean   : 0.01774                   Mean   :  0.2034
#  3rd Qu.: 0.00000                   3rd Qu.:  0.0000
#  Max.   :33.00000                   Max.   :683.0000
#
#  classNowAbstract_unstable classNowFinal_unstable classNoLongerPublic_unstable
#  Min.   :0.0000000         Min.   : 0.000000      Min.   :0.000000
#  1st Qu.:0.0000000         1st Qu.: 0.000000      1st Qu.:0.000000
#  Median :0.0000000         Median : 0.000000      Median :0.000000
#  Mean   :0.0006149         Mean   : 0.004304      Mean   :0.002987
#  3rd Qu.:0.0000000         3rd Qu.: 0.000000      3rd Qu.:0.000000
#  Max.   :1.0000000         Max.   :18.000000      Max.   :8.000000
#
#  classTypeChanged_unstable classNowCheckedException_unstable
#  Min.   :0.0000000         Min.   :0.00e+00
#  1st Qu.:0.0000000         1st Qu.:0.00e+00
#  Median :0.0000000         Median :0.00e+00
#  Mean   :0.0007906         Mean   :8.78e-05
#  3rd Qu.:0.0000000         3rd Qu.:0.00e+00
#  Max.   :2.0000000         Max.   :1.00e+00
#
#  classLessAccessible_unstable superclassRemoved_unstable
#  Min.   :0.000000             Min.   :  0.0000
#  1st Qu.:0.000000             1st Qu.:  0.0000
#  Median :0.000000             Median :  0.0000
#  Mean   :0.002987             Mean   :  0.2066
#  3rd Qu.:0.000000             3rd Qu.:  0.0000
#  Max.   :8.000000             Max.   :716.0000
#
#  superclassAdded_unstable superclassModifiedIncompatible_unstable
#  Min.   : 0.000000        Min.   :0
#  1st Qu.: 0.000000        1st Qu.:0
#  Median : 0.000000        Median :0
#  Mean   : 0.008257        Mean   :0
#  3rd Qu.: 0.000000        3rd Qu.:0
#  Max.   :26.000000        Max.   :0
#
#  interfaceAdded_unstable interfaceRemoved_unstable methodRemoved_unstable
#  Min.   :  0.00000       Min.   :   0.0000         Min.   :   0.000
#  1st Qu.:  0.00000       1st Qu.:   0.0000         1st Qu.:   0.000
#  Median :  0.00000       Median :   0.0000         Median :   0.000
#  Mean   :  0.08011       Mean   :   0.3914         Mean   :   1.419
#  3rd Qu.:  0.00000       3rd Qu.:   0.0000         3rd Qu.:   0.000
#  Max.   :192.00000       Max.   :2135.0000         Max.   :6149.000
#
#  methodRemovedInSuperclass_unstable methodLessAccessible_unstable
#  Min.   :  0.0000                   Min.   : 0.0000
#  1st Qu.:  0.0000                   1st Qu.: 0.0000
#  Median :  0.0000                   Median : 0.0000
#  Mean   :  0.1145                   Mean   : 0.0137
#  3rd Qu.:  0.0000                   3rd Qu.: 0.0000
#  Max.   :209.0000                   Max.   :27.0000
#
#  methodLessAccessibleThanInSuperclass_unstable methodMoreAccessible_unstable
#  Min.   :0                                     Min.   : 0.00000
#  1st Qu.:0                                     1st Qu.: 0.00000
#  Median :0                                     Median : 0.00000
#  Mean   :0                                     Mean   : 0.01168
#  3rd Qu.:0                                     3rd Qu.: 0.00000
#  Max.   :0                                     Max.   :25.00000
#
#  methodIsStaticAndOverridesNotStatic_unstable methodReturnTypeChanged_unstable
#  Min.   :0                                    Min.   : 0.00000
#  1st Qu.:0                                    1st Qu.: 0.00000
#  Median :0                                    Median : 0.00000
#  Mean   :0                                    Mean   : 0.02117
#  3rd Qu.:0                                    3rd Qu.: 0.00000
#  Max.   :0                                    Max.   :34.00000
#
#  methodNowAbstract_unstable methodNowFinal_unstable methodNowStatic_unstable
#  Min.   :0.000000           Min.   :0.000000        Min.   :0.000000
#  1st Qu.:0.000000           1st Qu.:0.000000        1st Qu.:0.000000
#  Median :0.000000           Median :0.000000        Median :0.000000
#  Mean   :0.001933           Mean   :0.001757        Mean   :0.002811
#  3rd Qu.:0.000000           3rd Qu.:0.000000        3rd Qu.:0.000000
#  Max.   :7.000000           Max.   :6.000000        Max.   :8.000000
#
#  methodNoLongerStatic_unstable methodAddedToInterface_unstable
#  Min.   :0.0000000             Min.   :  0.00000
#  1st Qu.:0.0000000             1st Qu.:  0.00000
#  Median :0.0000000             Median :  0.00000
#  Mean   :0.0009663             Mean   :  0.03224
#  3rd Qu.:0.0000000             3rd Qu.:  0.00000
#  Max.   :3.0000000             Max.   :100.00000
#
#  methodAddedToPublicClass_unstable methodNowThrowsCheckedException_unstable
#  Min.   :   0.000                  Min.   :0.00000
#  1st Qu.:   0.000                  1st Qu.:0.00000
#  Median :   0.000                  Median :0.00000
#  Mean   :   2.028                  Mean   :0.00202
#  3rd Qu.:   0.000                  3rd Qu.:0.00000
#  Max.   :6721.000                  Max.   :4.00000
#
#  methodAbstractAddedToClass_unstable methodAbstractAddedInSuperclass_unstable
#  Min.   : 0.000000                   Min.   :0.00000
#  1st Qu.: 0.000000                   1st Qu.:0.00000
#  Median : 0.000000                   Median :0.00000
#  Mean   : 0.009048                   Mean   :0.00123
#  3rd Qu.: 0.000000                   3rd Qu.:0.00000
#  Max.   :26.000000                   Max.   :3.00000
#
#  methodAbstractAddedInImplementedInterface_unstable methodNewDefault_unstable
#  Min.   : 0.000000                                  Min.   :0
#  1st Qu.: 0.000000                                  1st Qu.:0
#  Median : 0.000000                                  Median :0
#  Mean   : 0.001054                                  Mean   :0
#  3rd Qu.: 0.000000                                  3rd Qu.:0
#  Max.   :11.000000                                  Max.   :0
#
#  methodAbstractNowDefault_unstable fieldStaticAndOverridesStatic_unstable
#  Min.   :0                         Min.   :0
#  1st Qu.:0                         1st Qu.:0
#  Median :0                         Median :0
#  Mean   :0                         Mean   :0
#  3rd Qu.:0                         3rd Qu.:0
#  Max.   :0                         Max.   :0
#
#  fieldLessAccessibleThanInSuperclass_unstable fieldNowFinal_unstable
#  Min.   :0                                    Min.   :0.000000
#  1st Qu.:0                                    1st Qu.:0.000000
#  Median :0                                    Median :0.000000
#  Mean   :0                                    Mean   :0.001142
#  3rd Qu.:0                                    3rd Qu.:0.000000
#  Max.   :0                                    Max.   :4.000000
#
#  fieldNowStatic_unstable fieldNoLongerStatic_unstable fieldTypeChanged_unstable
#  Min.   :0.0000000       Min.   :0.00e+00             Min.   : 0.00000
#  1st Qu.:0.0000000       1st Qu.:0.00e+00             1st Qu.: 0.00000
#  Median :0.0000000       Median :0.00e+00             Median : 0.00000
#  Mean   :0.0001757       Mean   :8.78e-05             Mean   : 0.01326
#  3rd Qu.:0.0000000       3rd Qu.:0.00e+00             3rd Qu.: 0.00000
#  Max.   :2.0000000       Max.   :1.00e+00             Max.   :58.00000
#
#  fieldRemoved_unstable fieldRemovedInSuperclass_unstable
#  Min.   :   0.000      Min.   :  0.00000
#  1st Qu.:   0.000      1st Qu.:  0.00000
#  Median :   0.000      Median :  0.00000
#  Mean   :   0.621      Mean   :  0.04058
#  3rd Qu.:   0.000      3rd Qu.:  0.00000
#  Max.   :3304.000      Max.   :178.00000
#
#  fieldLessAccessible_unstable fieldMoreAccessible_unstable
#  Min.   : 0.00000             Min.   : 0.000000
#  1st Qu.: 0.00000             1st Qu.: 0.000000
#  Median : 0.00000             Median : 0.000000
#  Mean   : 0.00817             Mean   : 0.009399
#  3rd Qu.: 0.00000             3rd Qu.: 0.000000
#  Max.   :54.00000             Max.   :27.000000
#
#  constructorRemoved_unstable constructorLessAccessible_unstable
#  Min.   :  0.000             Min.   :0.000000
#  1st Qu.:  0.000             1st Qu.:0.000000
#  Median :  0.000             Median :0.000000
#  Mean   :  0.232             Mean   :0.004216
#  3rd Qu.:  0.000             3rd Qu.:0.000000
#  Max.   :784.000             Max.   :9.000000
#
#  bcs_unstablePkg   bin_compatible_unstablePkg src_compatible_unstablePkg
#  Min.   :    0.0   Length:11384               Length:11384
#  1st Qu.:    0.0   Class :character           Class :character
#  Median :    0.0   Mode  :character           Mode  :character
#  Mean   :    5.4
#  3rd Qu.:    0.0
#  Max.   :20783.0
#
#  expected_level_unstablePkg changes_unstablePkg added_unstablePkg
#  Length:11384               Min.   :    0.000   Min.   :    0.000
#  Class :character           1st Qu.:    0.000   1st Qu.:    0.000
#  Mode  :character           Median :    0.000   Median :    0.000
#                             Mean   :    8.738   Mean   :    4.968
#                             3rd Qu.:    0.000   3rd Qu.:    0.000
#                             Max.   :31462.000   Max.   :16022.000
#
#  removed_unstablePkg modified_unstablePkg broken_types_unstablePkg
#  Min.   :    0.000   Min.   :  0.000      Min.   :  0.0000
#  1st Qu.:    0.000   1st Qu.:  0.000      1st Qu.:  0.0000
#  Median :    0.000   Median :  0.000      Median :  0.0000
#  Mean   :    3.398   Mean   :  0.372      Mean   :  0.4169
#  3rd Qu.:    0.000   3rd Qu.:  0.000      3rd Qu.:  0.0000
#  Max.   :15247.000   Max.   :455.000      Max.   :883.0000
#
#  broken_methods_unstablePkg broken_fields_unstablePkg bcs_on_types_unstablePkg
#  Min.   :    0.000          Min.   :   0.000          Min.   :  0.0000
#  1st Qu.:    0.000          1st Qu.:   0.000          1st Qu.:  0.0000
#  Median :    0.000          Median :   0.000          Median :  0.0000
#  Mean   :    3.702          Mean   :   0.648          Mean   :  0.4456
#  3rd Qu.:    0.000          3rd Qu.:   0.000          3rd Qu.:  0.0000
#  Max.   :13699.000          Max.   :3335.000          Max.   :888.0000
#
#  bcs_on_methods_unstablePkg bcs_on_fields_unstablePkg
#  Min.   :    0.00           Min.   :   0.000
#  1st Qu.:    0.00           1st Qu.:   0.000
#  Median :    0.00           Median :   0.000
#  Mean   :    3.71           Mean   :   0.649
#  3rd Qu.:    0.00           3rd Qu.:   0.000
#  Max.   :13701.00           Max.   :3338.000
#
#  annotationDeprecatedAdded_unstablePkg classRemoved_unstablePkg
#  Min.   : 0.00000                      Min.   :  0.0000
#  1st Qu.: 0.00000                      1st Qu.:  0.0000
#  Median : 0.00000                      Median :  0.0000
#  Mean   : 0.01353                      Mean   :  0.1976
#  3rd Qu.: 0.00000                      3rd Qu.:  0.0000
#  Max.   :33.00000                      Max.   :683.0000
#
#  classNowAbstract_unstablePkg classNowFinal_unstablePkg
#  Min.   :0.0000000            Min.   : 0.000000
#  1st Qu.:0.0000000            1st Qu.: 0.000000
#  Median :0.0000000            Median : 0.000000
#  Mean   :0.0004392            Mean   : 0.003338
#  3rd Qu.:0.0000000            3rd Qu.: 0.000000
#  Max.   :1.0000000            Max.   :18.000000
#
#  classNoLongerPublic_unstablePkg classTypeChanged_unstablePkg
#  Min.   :0.00000                 Min.   :0.0000000
#  1st Qu.:0.00000                 1st Qu.:0.0000000
#  Median :0.00000                 Median :0.0000000
#  Mean   :0.00202                 Mean   :0.0004392
#  3rd Qu.:0.00000                 3rd Qu.:0.0000000
#  Max.   :8.00000                 Max.   :2.0000000
#
#  classNowCheckedException_unstablePkg classLessAccessible_unstablePkg
#  Min.   :0.00e+00                     Min.   :0.00000
#  1st Qu.:0.00e+00                     1st Qu.:0.00000
#  Median :0.00e+00                     Median :0.00000
#  Mean   :8.78e-05                     Mean   :0.00202
#  3rd Qu.:0.00e+00                     3rd Qu.:0.00000
#  Max.   :1.00e+00                     Max.   :8.00000
#
#  superclassRemoved_unstablePkg superclassAdded_unstablePkg
#  Min.   :  0.0000              Min.   : 0.000000
#  1st Qu.:  0.0000              1st Qu.: 0.000000
#  Median :  0.0000              Median : 0.000000
#  Mean   :  0.2009              Mean   : 0.008257
#  3rd Qu.:  0.0000              3rd Qu.: 0.000000
#  Max.   :716.0000              Max.   :26.000000
#
#  superclassModifiedIncompatible_unstablePkg interfaceAdded_unstablePkg
#  Min.   :0                                  Min.   :  0.00000
#  1st Qu.:0                                  1st Qu.:  0.00000
#  Median :0                                  Median :  0.00000
#  Mean   :0                                  Mean   :  0.07994
#  3rd Qu.:0                                  3rd Qu.:  0.00000
#  Max.   :0                                  Max.   :192.00000
#
#  interfaceRemoved_unstablePkg methodRemoved_unstablePkg
#  Min.   :   0.0000            Min.   :   0.00
#  1st Qu.:   0.0000            1st Qu.:   0.00
#  Median :   0.0000            Median :   0.00
#  Mean   :   0.3863            Mean   :   1.37
#  3rd Qu.:   0.0000            3rd Qu.:   0.00
#  Max.   :2135.0000            Max.   :6149.00
#
#  methodRemovedInSuperclass_unstablePkg methodLessAccessible_unstablePkg
#  Min.   :  0.000                       Min.   : 0.000000
#  1st Qu.:  0.000                       1st Qu.: 0.000000
#  Median :  0.000                       Median : 0.000000
#  Mean   :  0.113                       Mean   : 0.008433
#  3rd Qu.:  0.000                       3rd Qu.: 0.000000
#  Max.   :209.000                       Max.   :27.000000
#
#  methodLessAccessibleThanInSuperclass_unstablePkg
#  Min.   :0
#  1st Qu.:0
#  Median :0
#  Mean   :0
#  3rd Qu.:0
#  Max.   :0
#
#  methodMoreAccessible_unstablePkg
#  Min.   : 0.00000
#  1st Qu.: 0.00000
#  Median : 0.00000
#  Mean   : 0.01151
#  3rd Qu.: 0.00000
#  Max.   :25.00000
#
#  methodIsStaticAndOverridesNotStatic_unstablePkg
#  Min.   :0
#  1st Qu.:0
#  Median :0
#  Mean   :0
#  3rd Qu.:0
#  Max.   :0
#
#  methodReturnTypeChanged_unstablePkg methodNowAbstract_unstablePkg
#  Min.   : 0.00000                    Min.   :0.00000
#  1st Qu.: 0.00000                    1st Qu.:0.00000
#  Median : 0.00000                    Median :0.00000
#  Mean   : 0.02073                    Mean   :0.00123
# ...
#  Mean   :   46.79      Mean   :   9.773       Mean   : 0.01001
#  3rd Qu.:    1.00      3rd Qu.:   3.000       3rd Qu.: 0.00000
#  Max.   :43337.00      Max.   :6399.000       Max.   :10.00000
#
#  broken_methods_unstableAnnon broken_fields_unstableAnnon
#  Min.   : 0.00000             Min.   : 0.000000
#  1st Qu.: 0.00000             1st Qu.: 0.000000
#  Median : 0.00000             Median : 0.000000
#  Mean   : 0.07959             Mean   : 0.005885
#  3rd Qu.: 0.00000             3rd Qu.: 0.000000
#  Max.   :71.00000             Max.   :11.000000
#
#  bcs_on_types_unstableAnnon bcs_on_methods_unstableAnnon
#  Min.   : 0.00000           Min.   : 0.00000
#  1st Qu.: 0.00000           1st Qu.: 0.00000
#  Median : 0.00000           Median : 0.00000
#  Mean   : 0.01133           Mean   : 0.08222
#  3rd Qu.: 0.00000           3rd Qu.: 0.00000
#  Max.   :11.00000           Max.   :72.00000
#
#  bcs_on_fields_unstableAnnon annotationDeprecatedAdded_unstableAnnon
#  Min.   : 0.000000           Min.   : 0.000000
#  1st Qu.: 0.000000           1st Qu.: 0.000000
#  Median : 0.000000           Median : 0.000000
#  Mean   : 0.005885           Mean   : 0.004216
#  3rd Qu.: 0.000000           3rd Qu.: 0.000000
#  Max.   :11.000000           Max.   :11.000000
#
#  classRemoved_unstableAnnon classNowAbstract_unstableAnnon
#  Min.   : 0.000000          Min.   :0.0000000
#  1st Qu.: 0.000000          1st Qu.:0.0000000
#  Median : 0.000000          Median :0.0000000
#  Mean   : 0.005798          Mean   :0.0001757
#  3rd Qu.: 0.000000          3rd Qu.:0.0000000
#  Max.   :10.000000          Max.   :1.0000000
#
#  classNowFinal_unstableAnnon classNoLongerPublic_unstableAnnon
#  Min.   :0.0000000           Min.   :0.000000
#  1st Qu.:0.0000000           1st Qu.:0.000000
#  Median :0.0000000           Median :0.000000
#  Mean   :0.0009663           Mean   :0.000966
#  3rd Qu.:0.0000000           3rd Qu.:0.000000
#  Max.   :2.0000000           Max.   :4.000000
#
#  classTypeChanged_unstableAnnon classNowCheckedException_unstableAnnon
#  Min.   :0.0000000              Min.   :0
#  1st Qu.:0.0000000              1st Qu.:0
#  Median :0.0000000              Median :0
#  Mean   :0.0003514              Mean   :0
#  3rd Qu.:0.0000000              3rd Qu.:0
#  Max.   :1.0000000              Max.   :0
#
#  classLessAccessible_unstableAnnon superclassRemoved_unstableAnnon
#  Min.   :0.000000                  Min.   : 0.00000
#  1st Qu.:0.000000                  1st Qu.: 0.00000
#  Median :0.000000                  Median : 0.00000
#  Mean   :0.000966                  Mean   : 0.00571
#  3rd Qu.:0.000000                  3rd Qu.: 0.00000
#  Max.   :4.000000                  Max.   :10.00000
#
#  superclassAdded_unstableAnnon superclassModifiedIncompatible_unstableAnnon
#  Min.   :0                     Min.   :0
#  1st Qu.:0                     1st Qu.:0
#  Median :0                     Median :0
#  Mean   :0                     Mean   :0
#  3rd Qu.:0                     3rd Qu.:0
#  Max.   :0                     Max.   :0
#
#  interfaceAdded_unstableAnnon interfaceRemoved_unstableAnnon
#  Min.   :0.0000000            Min.   : 0.000000
#  1st Qu.:0.0000000            1st Qu.: 0.000000
#  Median :0.0000000            Median : 0.000000
#  Mean   :0.0001757            Mean   : 0.005095
#  3rd Qu.:0.0000000            3rd Qu.: 0.000000
#  Max.   :1.0000000            Max.   :15.000000
#
#  methodRemoved_unstableAnnon methodRemovedInSuperclass_unstableAnnon
#  Min.   : 0.00000            Min.   :0.000000
#  1st Qu.: 0.00000            1st Qu.:0.000000
#  Median : 0.00000            Median :0.000000
#  Mean   : 0.04919            Mean   :0.001581
#  3rd Qu.: 0.00000            3rd Qu.:0.000000
#  Max.   :54.00000            Max.   :4.000000
#
#  methodLessAccessible_unstableAnnon
#  Min.   : 0.000000
#  1st Qu.: 0.000000
#  Median : 0.000000
#  Mean   : 0.005271
#  3rd Qu.: 0.000000
#  Max.   :18.000000
#
#  methodLessAccessibleThanInSuperclass_unstableAnnon
#  Min.   :0
#  1st Qu.:0
#  Median :0
#  Mean   :0
#  3rd Qu.:0
#  Max.   :0
#
#  methodMoreAccessible_unstableAnnon
#  Min.   :0.0000000
#  1st Qu.:0.0000000
#  Median :0.0000000
#  Mean   :0.0001757
#  3rd Qu.:0.0000000
#  Max.   :1.0000000
#
#  methodIsStaticAndOverridesNotStatic_unstableAnnon
#  Min.   :0
#  1st Qu.:0
#  Median :0
#  Mean   :0
#  3rd Qu.:0
#  Max.   :0
#
#  methodReturnTypeChanged_unstableAnnon methodNowAbstract_unstableAnnon
#  Min.   :0.0000000                     Min.   :0.000000
#  1st Qu.:0.0000000                     1st Qu.:0.000000
#  Median :0.0000000                     Median :0.000000
#  Mean   :0.0004392                     Mean   :0.000703
#  3rd Qu.:0.0000000                     3rd Qu.:0.000000
#  Max.   :1.0000000                     Max.   :4.000000
#
#  methodNowFinal_unstableAnnon methodNowStatic_unstableAnnon
#  Min.   :0                    Min.   :0
#  1st Qu.:0                    1st Qu.:0
#  Median :0                    Median :0
#  Mean   :0                    Mean   :0
#  3rd Qu.:0                    3rd Qu.:0
#  Max.   :0                    Max.   :0
#
#  methodNoLongerStatic_unstableAnnon methodAddedToInterface_unstableAnnon
#  Min.   :0                          Min.   :0.000000
#  1st Qu.:0                          1st Qu.:0.000000
#  Median :0                          Median :0.000000
#  Mean   :0                          Mean   :0.000878
#  3rd Qu.:0                          3rd Qu.:0.000000
#  Max.   :0                          Max.   :5.000000
#
#  methodAddedToPublicClass_unstableAnnon
#  Min.   : 0.00000
#  1st Qu.: 0.00000
#  Median : 0.00000
#  Mean   : 0.01537
#  3rd Qu.: 0.00000
#  Max.   :25.00000
#
#  methodNowThrowsCheckedException_unstableAnnon
#  Min.   :0.0000000
#  1st Qu.:0.0000000
#  Median :0.0000000
#  Mean   :0.0001757
#  3rd Qu.:0.0000000
#  Max.   :1.0000000
#
#  methodAbstractAddedToClass_unstableAnnon
#  Min.   :0.000000
#  1st Qu.:0.000000
#  Median :0.000000
#  Mean   :0.001318
#  3rd Qu.:0.000000
#  Max.   :3.000000
#
#  methodAbstractAddedInSuperclass_unstableAnnon
#  Min.   :0
#  1st Qu.:0
#  Median :0
#  Mean   :0
#  3rd Qu.:0
#  Max.   :0
#
#  methodAbstractAddedInImplementedInterface_unstableAnnon
#  Min.   :0
#  1st Qu.:0
#  Median :0
#  Mean   :0
#  3rd Qu.:0
#  Max.   :0
#
#  methodNewDefault_unstableAnnon methodAbstractNowDefault_unstableAnnon
#  Min.   :0                      Min.   :0
#  1st Qu.:0                      1st Qu.:0
#  Median :0                      Median :0
#  Mean   :0                      Mean   :0
#  3rd Qu.:0                      3rd Qu.:0
#  Max.   :0                      Max.   :0
#
#  fieldStaticAndOverridesStatic_unstableAnnon
#  Min.   :0
#  1st Qu.:0
#  Median :0
#  Mean   :0
#  3rd Qu.:0
#  Max.   :0
#
#  fieldLessAccessibleThanInSuperclass_unstableAnnon fieldNowFinal_unstableAnnon
#  Min.   :0                                         Min.   :0
#  1st Qu.:0                                         1st Qu.:0
#  Median :0                                         Median :0
#  Mean   :0                                         Mean   :0
#  3rd Qu.:0                                         3rd Qu.:0
#  Max.   :0                                         Max.   :0
#
#  fieldNowStatic_unstableAnnon fieldNoLongerStatic_unstableAnnon
#  Min.   :0                    Min.   :0
#  1st Qu.:0                    1st Qu.:0
#  Median :0                    Median :0
#  Mean   :0                    Mean   :0
#  3rd Qu.:0                    3rd Qu.:0
#  Max.   :0                    Max.   :0
#
#  fieldTypeChanged_unstableAnnon fieldRemoved_unstableAnnon
#  Min.   :0                      Min.   : 0.000000
#  1st Qu.:0                      1st Qu.: 0.000000
#  Median :0                      Median : 0.000000
#  Mean   :0                      Mean   : 0.005885
#  3rd Qu.:0                      3rd Qu.: 0.000000
#  Max.   :0                      Max.   :11.000000
#
#  fieldRemovedInSuperclass_unstableAnnon fieldLessAccessible_unstableAnnon
#  Min.   :0                              Min.   :0
#  1st Qu.:0                              1st Qu.:0
#  Median :0                              Median :0
#  Mean   :0                              Mean   :0
#  3rd Qu.:0                              3rd Qu.:0
#  Max.   :0                              Max.   :0
#
#  fieldMoreAccessible_unstableAnnon constructorRemoved_unstableAnnon
#  Min.   :0                         Min.   : 0.000000
#  1st Qu.:0                         1st Qu.: 0.000000
#  Median :0                         Median : 0.000000
#  Mean   :0                         Mean   : 0.004568
#  3rd Qu.:0                         3rd Qu.: 0.000000
#  Max.   :0                         Max.   :11.000000
#
#  constructorLessAccessible_unstableAnnon unstableAnnons        jar_v1
#  Min.   :0.0000000                       Length:11384       Length:11384
#  1st Qu.:0.0000000                       Class :character   Class :character
#  Median :0.0000000                       Mode  :character   Mode  :character
#  Mean   :0.0002635
#  3rd Qu.:0.0000000
#  Max.   :3.0000000
#
#     jar_v2             delta            exception               t
#  Length:11384       Length:11384       Length:11384       Min.   :  0.000
#  Class :character   Class :character   Class :character   1st Qu.:  1.000
#  Mode  :character   Mode  :character   Mode  :character   Median :  1.000
#                                                           Mean   :  2.058
#                                                           3rd Qu.:  2.000
#                                                           Max.   :176.000
#
#    bcs_clean        bcs_clean_stable   bcs_ratio_clean
#  Min.   :    0.00   Min.   :    0.00   Min.   :0.000000
#  1st Qu.:    0.00   1st Qu.:    0.00   1st Qu.:0.000000
#  Median :    0.00   Median :    0.00   Median :0.000000
#  Mean   :   48.06   Mean   :   44.76   Mean   :0.020326
#  3rd Qu.:    2.00   3rd Qu.:    2.00   3rd Qu.:0.002202
#  Max.   :28953.00   Max.   :28953.00   Max.   :5.000000
#
#  bcs_ratio_clean_stable
#  Min.   :0.000000
#  1st Qu.:0.000000
#  Median :0.000000
#  Mean   :0.019010
#  3rd Qu.:0.001929
#  Max.   :5.000000

# %% [markdown]
# ### Descriptive Statistics
# This section presents some descriptive statistics on the dataset (number of clients, semver levels, popularity, releases, Java versions, etc.).

# %%
# Computes a density plot
# dataset: data frame with input data
# dim: vector with input data (column of the data frame)
# dim_label: name of the dimension 
# x_label: label of the x axis
# Returns a ggplot2 density plot
plot_dens_hist <- function(dataset, dim, dim_label, x_label, binw=30) {
    plot <- ggplot(dataset, aes(x=dim, y=..density..)) + 
        labs(title=sprintf("%s Density Histogram", dim_label),
             x=x_label,
             y="Density") +
        geom_histogram(binwidth=30) +
        geom_vline(aes(xintercept=median(dim)), 
                   linetype="dashed",
                   size=0.6)
    
    return(plot)
}

# %%
# Computes a density plot
# dataset: data frame with input data
# dim: vector with input data (column of the data frame)
# dim_label: name of the dimension 
# x_label: label of the x axis
# Returns a ggplot2 density plot
plot_dens_bar <- function(dataset, dim, dim_label, x_label) {
    plot <- ggplot(dataset, aes(x=dim, y=..prop.., group=1)) + 
        labs(title=sprintf("%s Density Histogram", dim_label),
             x=x_label,
             y="Density") +
        geom_bar() +
        ylim(0, 1) +
        theme_light(base_size=18)
    
    return(plot)
}

# %% [markdown]
# ### Java Versions

# %%
p <- plot_dens_bar(deltas, deltas$java_version_v1, "Java Versions", "Java version")
p
ggsave("figures/mdd-java-versions.pdf", p)
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ### Semantic Versioning Levels

# %%
p <- plot_dens_bar(deltas, deltas$level, "Semver Level", "Semver level")
p
ggsave("figures/mdd-semver-levels.pdf", p)
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ### Interval Between Releases
#
# The interval between releases is given in months.

# %%
plot_dens_bar(deltas, deltas$age_diff, "Age Difference", "Age diff")
# Out:
# plot without title

# %% [markdown]
# ### Age
#
# The age of the upgrade is relative to the first release of the library (in months).

# %%
plot_dens_bar(deltas, deltas$age, "Age", "Age")
# Out:
# plot without title

# %% [markdown]
# ---
#
# ## Results

# %% [markdown]
# ### Breaking Upgrades
# First, we study the number/ratio of breaking upgrades per semantic versioning level.

# %%
# Get datasets per semver level
major <- subset(deltas, level == "MAJOR")
minor <- subset(deltas, level == "MINOR")
patch <- subset(deltas, level == "PATCH")
devs <- subset(deltas, level == "DEV")

# %%
# Computes the number of breaking upgrades
number_breaking_upgrades <- function(dataset) {
    return (nrow(subset(dataset, bcs_clean_stable > 0)))
}

# Computes the percentage of breaking upgrades
perc_breaking_upgrades <- function(dataset) {
    return (nrow(subset(dataset, bcs_clean_stable > 0)) / nrow(dataset))
}

# Computes the percentage of breaking upgrades given a list of datasets
perc_breaking_upgrades_multiple <- function(datasets) {
    total <- 0
    cases <- 0
    
    for (d in datasets) {
        cases <- cases + nrow(subset(d, bcs_clean_stable > 0))
        total <- total + nrow(d)
    }
    return (cases / total)
}

# %%
# Get compound datasets
nrow_nonmajor <- nrow(minor) + nrow(patch)
nrow_all <- nrow_nonmajor + nrow(major) + nrow(devs)

breaking_upgrades <- data.frame(
    level = c("MAJOR", "MINOR", "PATCH", "DEV", "NON-MAJOR", "ALL"),
    number = c(nrow(major), nrow(minor), nrow(patch), nrow(devs), nrow_nonmajor, nrow_all),
    ratio = c(nrow(major) / nrow(deltas), nrow(minor) / nrow(deltas), nrow(patch) / nrow(deltas), nrow(devs) / nrow(deltas), nrow_nonmajor / nrow(deltas), nrow_all / nrow(deltas)),
    broken = c(number_breaking_upgrades(major),
               number_breaking_upgrades(minor),
               number_breaking_upgrades(patch),
               number_breaking_upgrades(devs),
               number_breaking_upgrades(minor) + number_breaking_upgrades(patch),
               number_breaking_upgrades(major) + number_breaking_upgrades(minor) + number_breaking_upgrades(patch) + number_breaking_upgrades(devs)),
    broken_ratio = c(perc_breaking_upgrades(major),
             perc_breaking_upgrades(minor),
             perc_breaking_upgrades(patch),
             perc_breaking_upgrades(devs),
             perc_breaking_upgrades_multiple(list(minor, patch)),
             perc_breaking_upgrades_multiple(list(major, minor, patch, devs)))
)

breaking_upgrades
# Out:
#   level     number ratio      broken broken_ratio
# 1 MAJOR       253  0.02222417  184   0.7272727
# 2 MINOR      2413  0.21196416 1228   0.5089101
# 3 PATCH      7728  0.67884751 1870   0.2419772
# 4 DEV         990  0.08696416  389   0.3929293
# 5 NON-MAJOR 10141  0.89081167 3098   0.3054926
# 6 ALL       11384  1.00000000 3671   0.3224701

# %%
ggplot(breaking_upgrades, aes(x=level, y=broken_ratio)) + 
        labs(title="Ratio of Breaking Upgrades per Semver Level",
             x="Semver level",
             y="Ratio of breaking upgrades") +
        geom_bar(stat="identity")
# Out:
# plot without title

# %% [markdown]
# ### Number of Breaking Changes

# %%
# Now we are only interested in breaking upgrades, so filter out the other ones
dt <- subset(deltas, bcs_clean_stable > 0)

# %%
summary(dt$bcs_clean_stable)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0     2.0     8.0   138.8    35.0 28953.0

# %%
summary(subset(dt, level == "MAJOR")$bcs_clean_stable)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0     8.0    52.0   371.5   202.5  7788.0

# %%
summary(subset(dt, level == "MINOR")$bcs_clean_stable)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0     3.0    13.0   157.3    53.0 16212.0

# %%
summary(subset(dt, level == "PATCH")$bcs_clean_stable)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#     1.00     2.00     6.00    92.51    21.00 28953.00

# %%
summary(subset(dt, level == "DEV")$bcs_clean_stable)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     1.0     4.0    12.0   192.9    46.0 21625.0

# %%
# Compute median value
med_fun <- function(x) {
    return (data.frame(y=median(x), label = round(10^median(x), digits=2)))
}

# Compute value of the first quantile
fstq_fun <- function(x) {
    return (data.frame(y=quantile(x)[2], label = round(10^(quantile(x)[2]), digits=2)))
}

# Compute value of the third quantile
thrq_fun <- function(x) {
    return (data.frame(y=quantile(x)[4], label = round(10^(quantile(x)[4]), digits=2)))
}

# Number of breaking changes per broken release per semantic versioning level
p <- ggplot(dt, aes(x=level, y=bcs_clean_stable)) +
    labs(x="Semver level", y="Number of BCs (log10 scale)") +
    geom_violin() +
    geom_boxplot(width=0.3, outlier.shape = NA, coef=0) +
    stat_summary(fun.data = med_fun, geom = "text", vjust=-0.5) +
    stat_summary(fun.data = fstq_fun, geom = "text", vjust=-0.5) +
    stat_summary(fun.data = thrq_fun, geom = "text", vjust=+1.5) +
    scale_y_continuous(trans='log10') +
    theme_light(base_size=18)

p
ggsave("figures/mdd-bc-number.pdf", p)
# Out:
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ### Breaking Change Types

# %%
# Exclude BCs that are not considered in the study
# which(colnames(deltas)=="classNowCheckedException") #41
# which(colnames(deltas)=="methodNowThrowsCheckedException") #61
# which(colnames(deltas)=="fieldStaticAndOverridesStatic") #67
# which(colnames(deltas)=="methodAbstractAddedInSuperclass") #63
# which(colnames(deltas)=="methodAbstractAddedInImplementedInterface") #64
# which(colnames(deltas)=="methodLessAccessibleThanInSuperclass") #51
# which(colnames(deltas)=="fieldLessAccessibleThanInSuperclass") #68
# which(colnames(deltas)=="fieldRemovedInSuperclass") #74
# which(colnames(deltas)=="methodRemovedInSuperclass") #49
# which(colnames(deltas)=="superclassModifiedIncompatible") #45
# which(colnames(deltas)=="methodIsStaticAndOverridesNotStatic") #53

# Get dataframe with semver level and BC types
f <- deltas[c(5, 36:40, 42:44, 46:48, 50, 52, 54:59, 62, 65:66, 69:73, 75:78)]

# %%
# Heatmap of occurences of breaking changes per semver level
formatted <- gather(f, "kind", "count", 2:32)

aggregated <- formatted %>%
    group_by(level, kind) %>%
    summarise(log_count=log10(sum(count)))

p <- ggplot(aggregated, aes(x=level, y=reorder(kind, log_count), fill=log_count)) +
    labs(x="Semver level", y="", fill="log10 count") +
    geom_tile() +
    scale_fill_gradientn(colours = c("white", "white", "lightgray", "black"), values = c(-Inf, 0, 0.1, 1)) +
    theme(axis.text.y = element_text(angle=0, size=12), axis.text.x = element_text(size=12), 
          legend.text = element_text(size=10), plot.background = element_rect(fill = "white"))

p
ggsave("figures/mdd-heatmap.pdf", p)
# Out:
# `summarise()` has grouped output by 'level'. You can override using the `.groups` argument.
#
# Saving 7 x 7 in image
# plot without title

# %%
# Histogram with number of breaking changes per semver level
formatted <- gather(f, "kind", "count", 2:32)

aggregated <- formatted %>%
    group_by(level, kind) %>%
    summarise(total=sum(count))

normalized <- aggregated %>%
    group_by(level) %>%
    summarise(kind = kind, ratio = total / sum(total)) %>%
    arrange(across(ratio, desc))

p <- ggplot(normalized, aes(x = reorder(kind,-ratio), y = ratio, fill = level)) + 
    labs(x = "BC kind", y = "Ratio", fill="Semver level") +
    geom_bar(stat = 'identity', position = 'dodge') +
    scale_fill_manual(values = c("grey0","grey30","grey50","grey80")) +
    ylim(0.0, 0.5) +
    theme_bw() + 
    theme(axis.text.x = element_text(angle = 66, vjust = 1, hjust = 1), aspect.ratio=0.75)

p
ggsave("figures/mdd-bc-kind-count.pdf")
# Out:
# `summarise()` has grouped output by 'level'. You can override using the `.groups` argument.
#
# `summarise()` has grouped output by 'level'. You can override using the `.groups` argument.
#
# Saving 7 x 7 in image
# plot without title

# %% [markdown]
# ---
#
# ## EOF
#
# > Lina Ochoa, Thomas Degueule, Jean-Rémy Falleri & Jurgen Vinju. Breaking Bad? Semantic Versioning and Impact of Breaking Changes in Maven Central. Journal of Empirical Software Engineering, 2021.
#
# This notebook—and all its content—is licensed under the [MIT License](https://choosealicense.com/licenses/mit/).
# © 2021 Maracas
